# %% [markdown]
# # IPYTHON

# %% [markdown]
# ## Shell or Notebook?

# %% [markdown]
# ## Help and Documentation in IPython

# %% [markdown]
# ### Accessing Documentation with ?

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %%
L=[1,2,3]

# %%
L?

# %%
L.insert??

# %%
a=2

# %% [markdown]
# ### Accessing Source Code with ??

# %%
def square(a):
    """Return the square of a."""
    return a**2

# %%
square?

# %%
square??

# %%
len??

# %% [markdown]
# ### Exploring Modules with Tab Completion

# %%
L = [1, 2, 3]

# %%
L.
# Out:
#   File "<ipython-input-12-9b66bc403048>", line 1
#     L.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## IPython Magic Commands

# %% [markdown]
# ### Pasting Code Blocks: %paste and %cpaste

# %%
def square(a):
    """Return the square of a."""
    return a**2

# %% [markdown]
# ### Timing Code Execution: %timeit

# %%
# %timeit?

# %% [markdown]
# #### With 1 line

# %%
# %timeit L = [n ** 2 for n in range(1000)]

# %% [markdown]
# #### with multiline

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n ** 2)

# %% [markdown]
# ### Help on Magic Functions: ?, %magic, and %lsmagic

# %%
# %magic

# %%
# %lsmagic

# %% [markdown]
# ### Input and Output History

# %% [markdown]
# #### IPython’s In and Out Objects

# %%
import math

# %%
math.sin(2)

# %%
math.cos(2)

# %%
print(In)

# %%
Out

# %% [markdown]
# ### Underscore Shortcuts and Previous Outputs

# %%
print(_)

# %%
print(__)

# %% [markdown]
# ### Suppressing Output

# %% [markdown]
# ### Related Magic Commands

# %% [markdown]
# ## Shell Commands in IPython

# %%
ls

# %%
# !pwd

# %%
# !echo "printing from the shell"

# %%
contents = !ls

# %%
print(contents)

# %%
directory = !pwd

# %%
print(directory)

# %%
type(directory)

# %% [markdown]
# ## Errors and Debugging

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def func1(a, b):
    return a / b
def func2(x):
    a = x
    b = x - 1
    return func1(a, b)

# %%
func2(1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %xmode Verbose

# %%
func2(1)

# %% [markdown]
# ### Debugging: When Reading Tracebacks Is Not Enough

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %debug

# %% [markdown]
# ## Profiling and Timing Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Timing Code Snippets: %timeit and %time

# %%
# %time

# %% [markdown]
# ### Profiling Full Scripts: %prun

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
    return total

# %%
# %prun sum_of_lists(1000000)

# %% [markdown]
# ### Line-by-Line Profiling with %lprun

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %lprun -f sum_of_lists sum_of_lists(5000)
#the time is reported in microseconds

# %%
# %lprun?

# %% [markdown]
# ### Profiling Memory Use: %memit and %mprun

# %%
# %load_ext memory_profiler
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
# %memit sum_of_lists(1000000)
# Out:
# peak memory: 142.57 MiB, increment: 63.65 MiB

# %%
# %%file mprun_demo.py
def sum_of_lists(N):
    total = 0
    for i in range(5):
    L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
        del L # remove reference to L
    return total
# Out:
# Overwriting mprun_demo.py

# %%
from mprun_demo.py import sum_of_lists
# %mprun -f sum_of_lists sum_of_lists(1000000)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\hoang\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-32-620e9c98b5dc>", line 1, in <module>
#     from mprun_demo.py import sum_of_lists
#
#   File "D:\develop\Data Science\data-science\Repos\SonHoang23\1. PythonDataScienceHandbook\PythonDataScienceHandbook-Chapter1-IPython\mprun_demo.py", line 4
#     L = [j ^ (j >> i) for j in range(N)]
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ## More IPython Resources
#
# page 30
