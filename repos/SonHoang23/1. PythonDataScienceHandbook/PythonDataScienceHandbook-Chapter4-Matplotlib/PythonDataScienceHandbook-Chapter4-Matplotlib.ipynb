# %% [markdown]
# # Visualization with Matplotlib

# %% [markdown]
# ## 1.General Matplotlib Tips

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('classic')

# %%
x=np.linspace(0,10,100)
#x

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# ## Save file

# %%
fig.savefig('my_figure.png')

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## 2.Two Interfaces for the Price of One

# %%
#its dual interface that can be a potentially confusing feature of Matplotlib: 
#a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface

# %% [markdown]
# ### MATLAB-style interface

# %%
# matplotlib khởi nguồn từ như một sự thay thế cho matlab và nhiều syntax phản chiếu từ đó
# MATLAB-style tools được bao gồm trong pyplot (plt)
# đại loại là nó tạo một đối tượng duy nhất ban đầu để vẽ,
# ok khi vẽ 1 cái nhưng vẽ cái thứ 2 thì làm sao quay về cái đầu để chỉnh sửa

# %% [markdown]
# ### Object-oriented interface

# %%
# đại loại là khắc phục được nhược điểm ở trên khi tạo cho mỗi hình là một đối tượng
# và cần gì thì tác động vào đối tượng đó

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ## 3.Simple Line Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
seaborn_whitegrid_style=plt
seaborn_whitegrid_style.style.use('seaborn-whitegrid')
print(seaborn_whitegrid_style.style.available) # các style
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### điều đầu tiên cần làm là tạo ảnh (figures) và các trục (axes)

# %%
fig = seaborn_whitegrid_style.figure()
ax = seaborn_whitegrid_style.axes()
# In Matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a
# single container that contains all the objects representing axes, graphics, text, and
# labels. The axes (an instance of the class plt.Axes) is what we see above: a bounding
# box with ticks and labels, which will eventually contain the plot elements that make
# up our visualization. Throughout this book, we’ll commonly use the variable name
# fig to refer to a figure instance, and ax to refer to an axes instance or group of axes
# instances.
x = np.linspace(0, 10, 1000) #khởi tạo một linear array
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

fig

# %%
seaborn_whitegrid_style.plot(x, x + 0, linestyle='solid')
seaborn_whitegrid_style.plot(x, x + 1, linestyle='dashed')
seaborn_whitegrid_style.plot(x, x + 2, linestyle='dashdot')
seaborn_whitegrid_style.plot(x, x + 3, linestyle='dotted');

# %%
#combine all color and linestyle
seaborn_whitegrid_style.plot(x, x + 0, '-g') # solid green
seaborn_whitegrid_style.plot(x, x + 1, '--c') # dashed cyan
seaborn_whitegrid_style.plot(x, x + 2, '-.k') # dashdot black
seaborn_whitegrid_style.plot(x, x + 3, ':r'); # dotted red
# full list line style: https://matplotlib.org/stable/api/markers_api.html

# %% [markdown]
# ### Adjusting the Plot: Axes Limits

# %%
limit_ases=plt
limit_ases.plot(x, np.sin(x))
limit_ases.xlim(-1,11)
limit_ases.ylim(-1,2)
# Out:
# (-1.0, 2.0)

# %% [markdown]
# #### Set limit in a function

# %%
limit_ases.plot(x, np.sin(x))
limit_ases.axis([-1,11,-1.5,1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %% [markdown]
# ### displayed in reverse

# %%
revert_plot=plt
revert_plot.plot(x, np.sin(x))
revert_plot.xlim(10, 0)
revert_plot.ylim(1.2, -1.2);

# %%
tighten_bounds_style=plt
tighten_bounds_style.plot(x,np.sin(x))
#tighten_bounds_style.axis('tight')
#tighten_bounds_style.axis('equal');

# %%
tighten_bounds_style.plot(x,np.sin(x))
tighten_bounds_style.axis('equal')
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %%
fig_test, ax_test = plt.subplots()
ax_test.plot(x, np.sin(x))
ax_test.plot(x, np.cos(x));
ax_test.plot(x, np.cos(x));

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.gca()
# Out:
# <AxesSubplot:title={'center':'A Sine Curve'}, xlabel='x', ylabel='sin(x)'>

# %% [markdown]
# #### Adjust position, size and style label

# %%
fig = plt.figure()
ax = plt.axes()
print(np.pi/2.)
ax.plot(x, np.sin(x), '-g', label='sin(x)') #x: Angle, in radians (2 \pi rad equals 360 degrees).
ax.plot(x, np.cos(x), ':b', label='cos(x)')
ax.plot(x, np.tan(x), '-.k', label='tan(x)')
ax.axis('equal')
ax.set_xlabel("x") # ~ plt.xlabel()
ax.set_ylabel("sin(x)") # ~ plt.ylabel() 
ax.set_xlim(-1,11) # ~ plt.xlim()
ax.set_ylim(-2,2) # ~ plt.ylim() 
ax.set_title("Adjust position, size and style label using ax") # ~ plt.title()
ax.legend(); #tạo label trong hình, Automatic detection of elements to be shown in the legend
# Out:
# 1.5707963267948966

# %% [markdown]
# ## 4.Simple Scatter Plots

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
x = np.linspace(0, 10, 30)
y = np.sin(x)

# %% [markdown]
# ### 4.1 Scatter Plots with plt.plot

# %%
rng= np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.randn(5), rng.randn(5), marker, label="maker='{0}'".format(marker))
plt.axis('equal')
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x,y, '-p', color='gray')

# %%
plt.plot(x,y, '-p', color='gray', markersize=15, linewidth=4, markerfacecolor='white', markeredgecolor='gray', markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ### 4.2 Scatter Plots with plt.scatter
# #### sự khác biệt giữa plt.plot() và plt.scatter() là tạo scatter plot nơi mỗi giá trị của mỗi điểm có thể được kiểm soát hoặc ánh xạ dữ liệu ??

# %%
plt.scatter(x,y, marker='o', color="orange" );
plt.colorbar();

# %%
rng = np.random.RandomState(0) #nôm na hiểu là: randomState => effect on funcs of this code but seed is effected on global everywhere
x = rng.randn(100)
x
#  y = rng.randn(100)
#  colors = rng.rand(100)
#  sizes = 1000 * rng.rand(100)
#  plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
#  cmap='viridis')
#  plt.colorbar(); # show color scale
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574,
#        -2.55298982,  0.6536186 ,  0.8644362 , -0.74216502,  2.26975462,
#        -1.45436567,  0.04575852, -0.18718385,  1.53277921,  1.46935877,
#         0.15494743,  0.37816252, -0.88778575, -1.98079647, -0.34791215,
#         0.15634897,  1.23029068,  1.20237985, -0.38732682, -0.30230275,
#        -1.04855297, -1.42001794, -1.70627019,  1.9507754 , -0.50965218,
#        -0.4380743 , -1.25279536,  0.77749036, -1.61389785, -0.21274028,
#        -0.89546656,  0.3869025 , -0.51080514, -1.18063218, -0.02818223,
#         0.42833187,  0.06651722,  0.3024719 , -0.63432209, -0.36274117,
#        -0.67246045, -0.35955316, -0.81314628, -1.7262826 ,  0.17742614,
# ...

# %%
x = rng.randn(100)
#print(x)
y = rng.randn(100)
#print(y)
colors = rng.rand(100)
#print(colors)
sizes = 1000 * rng.rand(100) #is given in pixel
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3            ,
cmap='viridis', marker='o')
# maker: https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers
plt.colorbar(); # show color scale

# %% [markdown]
# #### Load_iris

# %%
from sklearn.datasets import load_iris
iris= load_iris()
iris
features= iris.data.T
plt.scatter(features[0], features[1], alpha=0.2, s=100*features[3], c= iris.target, cmap="viridis")
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# #### note

# %%
# dùng thằng plot sẽ cho hiệu năng tốt hơn scatter 
# vì scatter phải rendering ra nhiều point với kích thước và màu sắc khác nhau 
# trong khi plot chỉ render và clone lại các điểm chỉ khác nhau về vị trí
# và sẽ thấy rõ sự khác biệt khi làm việc với dataset lớn

# %% [markdown]
# ## Visualizing Errors

# %% [markdown]
# ### Basic Errorbars

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')
x=np.linspace(0,10,50)
print(x)
dy= 0.8
y=np.sin(x)+dy*np.random.randn(50)
print(y)
plt.errorbar(x,y, yerr=dy, fmt='-.g')
plt.axis('equal')
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ]
# [ 1.25015084e-01  5.05071448e-01  3.99276446e-01  1.04990045e+00
#   1.07352437e+00  1.32569989e+00  1.55791324e+00  7.81265671e-01
#  -2.49183594e-02  1.14432429e+00  9.66414682e-01  1.23237120e+00
#   2.11040323e+00 -3.52897997e-01  2.06736418e+00  2.40161225e-01
#  -1.26171650e+00  1.62101690e-04 -1.16820864e+00 -9.46607232e-01
# ...

# %%
plt.errorbar(x, y, yerr=dy, xerr=dy, fmt='-', color='black',
 ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Continuous Errors

# %% [markdown]
# ## Three-Dimensional Plotting in Matplotlib

# %%
 from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))
x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
